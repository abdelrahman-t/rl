# %%
import sys
sys.path.append('..')

# %%
import pandas as pd
import numpy as np

from matplotlib.pyplot import *

from VectorMath import *
from Utilities import *

from keras import losses
from keras.layers import Dense, LSTM
from keras.models import Model, Sequential

from sklearn.metrics import mean_squared_error

# %%
# %matplotlib inline

np.random.seed=1

# %%
def get_sequence(X, y, time_steps):
    X_length, _ = X.shape
    y_length, _ = y.shape
    
    X_seq, y_seq = [], []
    for i in range(0, X_length-time_steps, time_steps):
        end = i + time_steps
        X_seq.append(X[i:end])
        y_seq.append(y[end-1])
    
    return np.array(X_seq), np.array(y_seq)
        
        
def build_model(input_shape, output_dim):
    model = Sequential()
    
    model.add(LSTM(units=48, input_shape=input_shape))
    model.add(Dense(units=output_dim, activation='linear'))
    model.compile(optimizer='rmsprop', loss='mse')
    
    return model

# %%
dataset = pd.read_csv('../datasets/10hz.csv')

length, _ = dataset.shape
#X, y = getXyAccelerationModel(dataset, limit=length, frequency=10.0)

# %%
time_steps = 5

# %%
X_sequence, y_sequence = get_sequence(X.values, y.values, time_steps=time_steps)

train = int(0.7 * X_sequence.shape[0])
xTrain, xTest, yTrain, yTest = X_sequence[:train], X_sequence[train:], y_sequence[:train], y_sequence[train:]

# %%
model = build_model(input_shape=(time_steps, 12), output_dim=6)
model.fit(xTrain, yTrain, epochs=900, batch_size=600, verbose=True)
# Out:
# Epoch 1/900
# 4988/4988 [==============================] - 1s 115us/step - loss: 13.3346
# Epoch 2/900
# 4988/4988 [==============================] - 0s 12us/step - loss: 13.1444
# Epoch 3/900
# 4988/4988 [==============================] - 0s 12us/step - loss: 12.9937
# Epoch 4/900
# 4988/4988 [==============================] - 0s 13us/step - loss: 12.8389
# Epoch 5/900
# 4988/4988 [==============================] - 0s 13us/step - loss: 12.6706
# Epoch 6/900
# 4988/4988 [==============================] - 0s 15us/step - loss: 12.4906
# Epoch 7/900
# 4988/4988 [==============================] - 0s 15us/step - loss: 12.2867
# Epoch 8/900
# 4988/4988 [==============================] - 0s 13us/step - loss: 12.0495
# Epoch 9/900
# 4988/4988 [==============================] - 0s 13us/step - loss: 11.7670
# Epoch 10/900
# 4988/4988 [==============================] - 0s 12us/step - loss: 11.4597
# Epoch 11/900
# 4988/4988 [==============================] - 0s 12us/step - loss: 11.1300
# ...

# %%
yPredicted = pd.DataFrame(model.predict(xTest), columns=y.columns)
yTest_df = pd.DataFrame(yTest, columns=y.columns)

print('RMSE on test dataset:\n---')

for i in y.columns:
    print(i + '\t', mean_squared_error(yPredicted[i], yTest_df[i]) ** 0.5)
# Out:
# RMSE on test dataset:
# ---
# d2XB	 0.379233493622
# d2YB	 0.248864558509
# d2ZB	 0.250335302589
# d2Roll	 0.641176540407
# d2Pitch	 0.660849259247
# d2Yaw	 0.247038288745

# %%
X.head()
# Out:
#             dXB           dYB       dZB         dRoll        dPitch  \
# 0  3.773568e-08 -2.547819e-10 -0.259528 -2.071970e-15  1.394288e-07
# 1  3.803169e-08 -2.473371e-10 -0.907338 -2.111236e-15 -2.269107e-08
# 2  3.967851e-08 -2.548618e-10 -1.601208 -2.087381e-15 -2.269113e-08
# 3  4.104151e-08 -2.548829e-10 -2.249746 -2.059446e-15 -2.269112e-08
# 4  4.334758e-08 -2.549459e-10 -2.860831 -2.030748e-15 -2.269113e-08
#
#            dYaw          roll         pitch  moveForward  yawCCW  yawCW  hover
# 0  5.979928e-09 -3.740099e-14 -1.924554e-09          0.0     0.0    0.0    1.0
# 1  7.448762e-09 -3.761524e-14 -4.193661e-09          0.0     0.0    0.0    1.0
# 2  1.102308e-08 -3.783110e-14 -6.462774e-09          0.0     0.0    0.0    1.0
# 3  1.250328e-08 -3.804796e-14 -8.731886e-09          0.0     0.0    0.0    1.0
# 4  1.519993e-08 -3.826776e-14 -1.100100e-08          0.0     0.0    0.0    1.0

# %%
figure(num=None, figsize=(15, 5), dpi=80, facecolor='w', edgecolor='k')

limit = 20
shift = np.random.randint(xTest.shape[0]-limit)
prediction_error = np.zeros((limit, 6))

euler = toEulerianAngle(dataset.loc[train+shift, ['scalar', 'i', 'j', 'k']].values)
gen2 = predict(xTest[['moveForward', 'yawCCW', 'yawCW', 'hover']].values[shift:],
               np.concatenate((dataset.loc[train+shift, ['x', 'y', 'z']].values, euler)), xTest.iloc[shift].values, 10.0)


for i in range(1, limit):
    p, o = next(gen2)

    pTrue = dataset.loc[i+train+shift, ['x', 'y', 'z']]
    oTrue = dataset.loc[i+train+shift, ['roll', 'pitch', 'yaw']]
    plt.scatter(pTrue[0], pTrue[1], color='green')

    plt.scatter(p[0], p[1], color='red')
    
    #prediction_error[i-1] = np.concatenate((p-pTrue, np.rad2deg(getAverageAngularVelocity(oTrue, o, 1.0))))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-92-e2ddefdb1031> in <module>()
#       6
#       7 euler = toEulerianAngle(dataset.loc[train+shift, ['scalar', 'i', 'j', 'k']].values)
# ----> 8 gen2 = predict(xTest[['moveForward', 'yawCCW', 'yawCW', 'hover']].values[shift:],
#       9                np.concatenate((dataset.loc[train+shift, ['x', 'y', 'z']].values, euler)), xTest.iloc[shift].values, 10.0)
#      10
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices
